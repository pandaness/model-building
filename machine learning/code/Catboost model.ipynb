# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import joblib

# Read the CSV file
data = pd.read_csv('23 feature.csv', sep=',')

# Use the first column as the dependent variable and the other columns as the independent variables
X = data.iloc[:, 1:]
y = data.iloc[:, 0]

# Divide the data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=56)
# Normalize the training and test sets using the mean and standard deviation of the training set
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Decision tree selection features using embedded methods
dt = DecisionTreeRegressor(random_state=5) 
dt.fit(X_train_scaled, y_train)

# Select the 15 most important features
feature_importance = pd.Series(dt.feature_importances_, index=X.columns)
top_15_features = feature_importance.nlargest(15).index.tolist()
X_train_selected = X_train[top_15_features]
X_test_selected = X_test[top_15_features]

# Export the selected feature values
X_train_selected.to_csv("selected_features_train.csv", index=False)
X_test_selected.to_csv("selected_features_test.csv", index=False)

# Calculate the correlation matrix
correlation_matrix = X_train_selected.corr()

# Find features with a correlation greater than 0.8
highly_correlated = set()
n_cols = correlation_matrix.shape[1]
for i in range(n_cols):
    for j in range(i + 1, n_cols):
        correlation = correlation_matrix.iloc[i, j]
        if correlation > 0.8:
            colname_i = correlation_matrix.columns[i]
            colname_j = correlation_matrix.columns[j]
            if colname_i not in highly_correlated:
                highly_correlated.add(colname_j)

# Remove features with high relevance
X_train_final = X_train_selected.drop(columns=highly_correlated)
X_test_final = X_test_selected.drop(columns=highly_correlated)

#STD and MEAN for the final feature is obtained
mean_values = X_train_final.mean()
std_values = X_train_final.std()
feature_names = X_train_final.columns.tolist()
data = pd.DataFrame([mean_values, std_values], columns=feature_names)
data.to_csv('mean_std.csv', index=False)

# Export the final list of features
selected_features = X_train_final.columns.tolist()
with open("selected_features.txt", "w") as file:
    file.write("\n".join(selected_features))

print(selected_features)   
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# Specify the font properties
font_properties = fm.FontProperties(family="Times New Roman", size=10)

# Calculate the correlation matrix after removing highly correlated features
correlation_matrix_final = X_train_final.corr()

# Create the heatmap
ax = sns.heatmap(correlation_matrix_final, annot=False, cmap="coolwarm")

# Set the font properties for the annotations
for text in ax.texts:
    text.set_fontproperties(font_properties)

plt.title("Correlation Matrix of Selected Features (After Removing Highly Correlated Features)")
plt.savefig('1.jpg', dpi=300, bbox_inches='tight')
plt.close()

# Create the heatmap of the original selected features correlation matrix
ax = sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm")

# Set the font properties for the annotations
for text in ax.texts:
    text.set_fontproperties(font_properties)

plt.title("Correlation Matrix of Selected Features")
plt.savefig('2.jpg', dpi=300, bbox_inches='tight')
plt.close()

# Define CatBoost regression models and hyperparameter spaces
model = CatBoostRegressor()
params = {'depth': [4], 'learning_rate': [0.109], 'iterations': [66]}

# Use grid search and 5-fold cross-validation to find the optimal hyperparameters
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=5)
grid_search.fit(X_train_final, y_train)

# Output the optimal hyperparameters
print("Best parameters:", grid_search.best_params_)

# Get the optimal model
best_model = grid_search.best_estimator_

# Use the training set to calculate metrics such as R-square, MAE, MSE, and RMSE
y_train_pred = best_model.predict(X_train_final)
r2_train = r2_score(y_train, y_train_pred)
mae_train = mean_absolute_error(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
rmse_train = mean_squared_error(y_train, y_train_pred, squared=False)

print("Training set R2 score:", r2_train)
print("Training set MAE:", mae_train)
print("Training set MSE:", mse_train)
print("Training set RMSE:", rmse_train)

# Use the test set to calculate metrics such as R-square, MAE, MSE, and RMSE
y_test_pred = best_model.predict(X_test_final)
r2_test = r2_score(y_test, y_test_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
rmse_test = mean_squared_error(y_test, y_test_pred, squared=False)

print("Test set R2 score:", r2_test)
print("Test set MAE:", mae_test)
print("Test set MSE:", mse_test)
print("Test set RMSE:", rmse_test)

joblib.dump(best_model, 'CatBoost.joblib')

# Export the prediction results of the training set as a CSV file containing the index number of the original data
train_predictions = pd.DataFrame({'Index': X_train_final.index, 'Actual': y_train, 'Predicted': y_train_pred})
train_predictions.to_csv('train_predictions.csv', index=False)

# Export the prediction results of the test set as a CSV file containing the index number of the original data
test_predictions = pd.DataFrame({'Index': X_test_final.index, 'Actual': y_test, 'Predicted': y_test_pred})
test_predictions.to_csv('test_predictions.csv', index=False)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# plot training set actual vs predicted values
plt.scatter(y_train, y_train_pred, alpha=0.5, label='Training Set')

z_train = np.polyfit(y_train, y_train_pred, 1)
p_train = np.poly1d(z_train)
plt.plot(y_train, p_train(y_train), '-', color='blue', label='Training Set Trend')

# plot testing set actual vs predicted values
plt.scatter(y_test, y_test_pred, alpha=0.5, label='Testing Set')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')
z_test = np.polyfit(y_test, y_test_pred, 1)
p_test = np.poly1d(z_test)
plt.plot(y_test, p_test(y_test), '-', color='orange', label='Testing Set Trend')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], 'r--', label='Ideal Relationship')
# set axis labels and legend
plt.xlabel('Actual Values', fontname='Times New Roman')
plt.ylabel('Predicted Values', fontname='Times New Roman')
plt.legend()

# compute and display R-squared values
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)
plt.text(0.75, 0.1, f'Training Set R-squared = {train_r2:.3f}\nTesting Set R-squared = {test_r2:.3f}', 
         horizontalalignment='center', verticalalignment='top', transform=plt.gca().transAxes, fontname='Times New Roman')

# plot trend lines with blue and orange colors
plt.plot(y_train, p_train(y_train), '-', color='blue', label='Training Set Trend')
plt.plot(y_test, p_test(y_test), '-', color='orange', label='Testing Set Trend')
# add title
plt.title('CatBoost', fontname='Times New Roman')

# save plot as JPG file
plt.savefig('my_plot.jpg', dpi=300, bbox_inches='tight')
# Out:
# ['Chi2v', 'MaxAbsPartialCharge', 'MolLogP', 'BCUT2D_MRHI', 'Kappa3', 'SMR_VSA5', 'TPSA', 'PEOE_VSA7', 'VSA_EState4', 'SlogP_VSA6', 'BCUT2D_MRLOW', 'Binding Energy', 'EState_VSA4']
# 0:	learn: 1.1871731	total: 144ms	remaining: 9.36s
# 1:	learn: 1.1454484	total: 144ms	remaining: 4.62s
# 2:	learn: 1.1095502	total: 145ms	remaining: 3.04s
# 3:	learn: 1.0668122	total: 145ms	remaining: 2.25s
# 4:	learn: 1.0204727	total: 145ms	remaining: 1.77s
# 5:	learn: 0.9764886	total: 145ms	remaining: 1.45s
# 6:	learn: 0.9560985	total: 146ms	remaining: 1.23s
# 7:	learn: 0.9322893	total: 146ms	remaining: 1.06s
# 8:	learn: 0.8997854	total: 146ms	remaining: 925ms
# 9:	learn: 0.8695187	total: 146ms	remaining: 820ms
# 10:	learn: 0.8540855	total: 147ms	remaining: 733ms
# 11:	learn: 0.8209494	total: 147ms	remaining: 661ms
# 12:	learn: 0.7984192	total: 147ms	remaining: 600ms
# 13:	learn: 0.7753906	total: 147ms	remaining: 547ms
# 14:	learn: 0.7477189	total: 148ms	remaining: 502ms
# 15:	learn: 0.7374984	total: 148ms	remaining: 462ms
# 16:	learn: 0.7203332	total: 148ms	remaining: 427ms
# 17:	learn: 0.7097743	total: 148ms	remaining: 395ms
# 18:	learn: 0.6846077	total: 148ms	remaining: 367ms
# 19:	learn: 0.6691051	total: 149ms	remaining: 342ms
# 20:	learn: 0.6432892	total: 149ms	remaining: 319ms
# 21:	learn: 0.6216667	total: 149ms	remaining: 298ms
# 22:	learn: 0.6097838	total: 149ms	remaining: 279ms
# 23:	learn: 0.5944090	total: 150ms	remaining: 262ms
# 24:	learn: 0.5880628	total: 150ms	remaining: 246ms
# 25:	learn: 0.5703005	total: 150ms	remaining: 231ms
# 26:	learn: 0.5541802	total: 150ms	remaining: 217ms
# 27:	learn: 0.5462493	total: 150ms	remaining: 204ms
# 28:	learn: 0.5346388	total: 151ms	remaining: 192ms
# 29:	learn: 0.5212859	total: 151ms	remaining: 181ms
# 30:	learn: 0.5116485	total: 151ms	remaining: 170ms
# 31:	learn: 0.5059426	total: 151ms	remaining: 161ms
# 32:	learn: 0.4895663	total: 151ms	remaining: 151ms
# 33:	learn: 0.4782057	total: 152ms	remaining: 143ms
# 34:	learn: 0.4740706	total: 152ms	remaining: 134ms
# 35:	learn: 0.4674531	total: 152ms	remaining: 127ms
# 36:	learn: 0.4538477	total: 152ms	remaining: 119ms
# 37:	learn: 0.4460390	total: 152ms	remaining: 112ms
# 38:	learn: 0.4392960	total: 153ms	remaining: 106ms
# 39:	learn: 0.4352219	total: 153ms	remaining: 99.3ms
# 40:	learn: 0.4310592	total: 153ms	remaining: 93.3ms
# 41:	learn: 0.4233816	total: 153ms	remaining: 87.5ms
# 42:	learn: 0.4142101	total: 153ms	remaining: 82ms
# 43:	learn: 0.4035375	total: 154ms	remaining: 76.8ms
# 44:	learn: 0.3962632	total: 154ms	remaining: 71.7ms
# 45:	learn: 0.3905608	total: 154ms	remaining: 66.9ms
# 46:	learn: 0.3876383	total: 154ms	remaining: 62.3ms
# 47:	learn: 0.3833156	total: 154ms	remaining: 57.9ms
# 48:	learn: 0.3781516	total: 155ms	remaining: 53.6ms
# 49:	learn: 0.3753179	total: 155ms	remaining: 49.5ms
# 50:	learn: 0.3722595	total: 155ms	remaining: 45.6ms
# 51:	learn: 0.3618683	total: 155ms	remaining: 41.8ms
# 52:	learn: 0.3575102	total: 155ms	remaining: 38.1ms
# 53:	learn: 0.3506475	total: 155ms	remaining: 34.5ms
# 54:	learn: 0.3466562	total: 156ms	remaining: 31.1ms
# 55:	learn: 0.3430118	total: 156ms	remaining: 27.8ms
# 56:	learn: 0.3395752	total: 156ms	remaining: 24.6ms
# 57:	learn: 0.3360552	total: 156ms	remaining: 21.6ms
# 58:	learn: 0.3320405	total: 156ms	remaining: 18.6ms
# 59:	learn: 0.3288694	total: 157ms	remaining: 15.7ms
# 60:	learn: 0.3259515	total: 157ms	remaining: 12.9ms
# 61:	learn: 0.3232134	total: 157ms	remaining: 10.1ms
# 62:	learn: 0.3178936	total: 157ms	remaining: 7.5ms
# 63:	learn: 0.3105620	total: 158ms	remaining: 4.92ms
# 64:	learn: 0.3081064	total: 158ms	remaining: 2.43ms
# 65:	learn: 0.3014841	total: 158ms	remaining: 0us
# 0:	learn: 1.1958427	total: 251us	remaining: 16.4ms
# 1:	learn: 1.1602031	total: 461us	remaining: 14.8ms
# 2:	learn: 1.0979835	total: 645us	remaining: 13.6ms
# 3:	learn: 1.0577572	total: 844us	remaining: 13.1ms
# 4:	learn: 1.0025314	total: 1.02ms	remaining: 12.5ms
# 5:	learn: 0.9495713	total: 1.2ms	remaining: 12ms
# 6:	learn: 0.9232063	total: 1.38ms	remaining: 11.6ms
# 7:	learn: 0.8865014	total: 1.54ms	remaining: 11.2ms
# 8:	learn: 0.8571165	total: 1.72ms	remaining: 10.9ms
# 9:	learn: 0.8202188	total: 1.89ms	remaining: 10.6ms
# 10:	learn: 0.7948951	total: 2.07ms	remaining: 10.3ms
# 11:	learn: 0.7642367	total: 2.23ms	remaining: 10ms
# 12:	learn: 0.7479461	total: 2.4ms	remaining: 9.77ms
# 13:	learn: 0.7202734	total: 2.57ms	remaining: 9.55ms
# 14:	learn: 0.7053186	total: 2.74ms	remaining: 9.32ms
# 15:	learn: 0.6875899	total: 2.92ms	remaining: 9.13ms
# 16:	learn: 0.6645390	total: 3.09ms	remaining: 8.91ms
# 17:	learn: 0.6417610	total: 3.26ms	remaining: 8.69ms
# 18:	learn: 0.6157602	total: 3.44ms	remaining: 8.5ms
# 19:	learn: 0.6018580	total: 3.61ms	remaining: 8.3ms
# 20:	learn: 0.5776882	total: 3.78ms	remaining: 8.1ms
# 21:	learn: 0.5636441	total: 3.94ms	remaining: 7.88ms
# 22:	learn: 0.5456041	total: 4.11ms	remaining: 7.67ms
# 23:	learn: 0.5273679	total: 4.29ms	remaining: 7.51ms
# 24:	learn: 0.5164405	total: 4.47ms	remaining: 7.33ms
# 25:	learn: 0.4977017	total: 4.63ms	remaining: 7.13ms
# 26:	learn: 0.4879625	total: 4.81ms	remaining: 6.94ms
# 27:	learn: 0.4809383	total: 4.98ms	remaining: 6.76ms
# 28:	learn: 0.4755887	total: 5.16ms	remaining: 6.59ms
# 29:	learn: 0.4626445	total: 5.33ms	remaining: 6.4ms
# 30:	learn: 0.4476543	total: 5.51ms	remaining: 6.22ms
# 31:	learn: 0.4408730	total: 5.67ms	remaining: 6.03ms
# 32:	learn: 0.4310427	total: 5.84ms	remaining: 5.84ms
# 33:	learn: 0.4217209	total: 6ms	remaining: 5.65ms
# 34:	learn: 0.4133253	total: 6.16ms	remaining: 5.46ms
# 35:	learn: 0.3995050	total: 6.33ms	remaining: 5.28ms
# 36:	learn: 0.3941316	total: 6.51ms	remaining: 5.11ms
# 37:	learn: 0.3857194	total: 6.68ms	remaining: 4.92ms
# 38:	learn: 0.3788678	total: 6.85ms	remaining: 4.75ms
# 39:	learn: 0.3678741	total: 7.03ms	remaining: 4.57ms
# 40:	learn: 0.3584138	total: 7.2ms	remaining: 4.39ms
# 41:	learn: 0.3519641	total: 7.36ms	remaining: 4.21ms
# 42:	learn: 0.3474436	total: 7.53ms	remaining: 4.03ms
# 43:	learn: 0.3392336	total: 7.8ms	remaining: 3.9ms
# 44:	learn: 0.3301408	total: 8.07ms	remaining: 3.77ms
# 45:	learn: 0.3204163	total: 8.31ms	remaining: 3.61ms
# 46:	learn: 0.3143641	total: 8.57ms	remaining: 3.46ms
# 47:	learn: 0.3064344	total: 8.78ms	remaining: 3.29ms
# 48:	learn: 0.2972150	total: 8.96ms	remaining: 3.11ms
# 49:	learn: 0.2891660	total: 9.13ms	remaining: 2.92ms
# 50:	learn: 0.2819053	total: 9.31ms	remaining: 2.74ms
# 51:	learn: 0.2756910	total: 9.53ms	remaining: 2.57ms
# 52:	learn: 0.2705290	total: 9.72ms	remaining: 2.38ms
# 53:	learn: 0.2668980	total: 9.89ms	remaining: 2.2ms
# 54:	learn: 0.2605121	total: 10.1ms	remaining: 2.01ms
# 55:	learn: 0.2537130	total: 10.2ms	remaining: 1.83ms
# 56:	learn: 0.2482587	total: 10.4ms	remaining: 1.65ms
# 57:	learn: 0.2414938	total: 10.7ms	remaining: 1.47ms
# 58:	learn: 0.2351260	total: 10.9ms	remaining: 1.29ms
# 59:	learn: 0.2293507	total: 11.1ms	remaining: 1.1ms
# 60:	learn: 0.2238236	total: 11.2ms	remaining: 920us
# 61:	learn: 0.2188371	total: 11.4ms	remaining: 736us
# 62:	learn: 0.2150030	total: 11.6ms	remaining: 551us
# 63:	learn: 0.2097837	total: 11.7ms	remaining: 367us
# 64:	learn: 0.2047275	total: 11.9ms	remaining: 183us
# 65:	learn: 0.2005153	total: 12.1ms	remaining: 0us
# 0:	learn: 1.3247147	total: 266us	remaining: 17.3ms
# 1:	learn: 1.2627178	total: 478us	remaining: 15.3ms
# 2:	learn: 1.2188795	total: 670us	remaining: 14.1ms
# 3:	learn: 1.1498736	total: 865us	remaining: 13.4ms
# 4:	learn: 1.0894524	total: 1.05ms	remaining: 12.8ms
# 5:	learn: 1.0375604	total: 1.22ms	remaining: 12.2ms
# 6:	learn: 0.9890099	total: 1.4ms	remaining: 11.8ms
# 7:	learn: 0.9651727	total: 1.58ms	remaining: 11.4ms
# 8:	learn: 0.9176007	total: 1.76ms	remaining: 11.1ms
# 9:	learn: 0.8843654	total: 1.94ms	remaining: 10.9ms
# 10:	learn: 0.8430463	total: 2.13ms	remaining: 10.6ms
# 11:	learn: 0.8143951	total: 2.32ms	remaining: 10.4ms
# 12:	learn: 0.7838570	total: 2.49ms	remaining: 10.2ms
# 13:	learn: 0.7598526	total: 2.67ms	remaining: 9.92ms
# 14:	learn: 0.7286136	total: 2.86ms	remaining: 9.72ms
# 15:	learn: 0.7134465	total: 3.06ms	remaining: 9.56ms
# 16:	learn: 0.6899234	total: 3.27ms	remaining: 9.43ms
# 17:	learn: 0.6758838	total: 3.47ms	remaining: 9.24ms
# 18:	learn: 0.6602456	total: 3.64ms	remaining: 9ms
# 19:	learn: 0.6444863	total: 3.82ms	remaining: 8.79ms
# 20:	learn: 0.6260679	total: 4.01ms	remaining: 8.59ms
# 21:	learn: 0.6095229	total: 4.23ms	remaining: 8.47ms
# 22:	learn: 0.5922565	total: 4.43ms	remaining: 8.29ms
# 23:	learn: 0.5743483	total: 4.61ms	remaining: 8.07ms
# 24:	learn: 0.5695175	total: 4.78ms	remaining: 7.84ms
# 25:	learn: 0.5498507	total: 4.96ms	remaining: 7.64ms
# 26:	learn: 0.5381333	total: 5.15ms	remaining: 7.44ms
# 27:	learn: 0.5301862	total: 5.34ms	remaining: 7.25ms
# 28:	learn: 0.5236503	total: 5.54ms	remaining: 7.07ms
# 29:	learn: 0.5043649	total: 5.73ms	remaining: 6.88ms
# 30:	learn: 0.4912727	total: 5.99ms	remaining: 6.76ms
# 31:	learn: 0.4833572	total: 6.2ms	remaining: 6.58ms
# 32:	learn: 0.4757834	total: 6.39ms	remaining: 6.39ms
# 33:	learn: 0.4665467	total: 6.59ms	remaining: 6.2ms
# 34:	learn: 0.4595610	total: 6.78ms	remaining: 6ms
# 35:	learn: 0.4498602	total: 6.95ms	remaining: 5.79ms
# 36:	learn: 0.4448577	total: 7.12ms	remaining: 5.58ms
# 37:	learn: 0.4372680	total: 7.29ms	remaining: 5.37ms
# 38:	learn: 0.4279133	total: 7.48ms	remaining: 5.18ms
# 39:	learn: 0.4194102	total: 7.68ms	remaining: 4.99ms
# 40:	learn: 0.4120326	total: 7.86ms	remaining: 4.79ms
# 41:	learn: 0.4030353	total: 8.03ms	remaining: 4.59ms
# 42:	learn: 0.3948301	total: 8.2ms	remaining: 4.38ms
# 43:	learn: 0.3839497	total: 8.4ms	remaining: 4.2ms
# 44:	learn: 0.3767498	total: 8.57ms	remaining: 4ms
# 45:	learn: 0.3712244	total: 8.74ms	remaining: 3.8ms
# 46:	learn: 0.3611045	total: 8.95ms	remaining: 3.62ms
# 47:	learn: 0.3542288	total: 9.16ms	remaining: 3.44ms
# 48:	learn: 0.3475158	total: 9.35ms	remaining: 3.24ms
# 49:	learn: 0.3438113	total: 9.52ms	remaining: 3.05ms
# 50:	learn: 0.3418202	total: 9.74ms	remaining: 2.87ms
# 51:	learn: 0.3391214	total: 10ms	remaining: 2.69ms
# 52:	learn: 0.3347156	total: 10.2ms	remaining: 2.5ms
# 53:	learn: 0.3245194	total: 10.4ms	remaining: 2.3ms
# 54:	learn: 0.3193473	total: 10.5ms	remaining: 2.11ms
# 55:	learn: 0.3135523	total: 10.8ms	remaining: 1.92ms
# 56:	learn: 0.3086227	total: 11ms	remaining: 1.73ms
# 57:	learn: 0.3051106	total: 11.1ms	remaining: 1.53ms
# 58:	learn: 0.2993483	total: 11.3ms	remaining: 1.34ms
# 59:	learn: 0.2972715	total: 11.5ms	remaining: 1.15ms
# 60:	learn: 0.2949620	total: 11.7ms	remaining: 958us
# 61:	learn: 0.2868526	total: 11.9ms	remaining: 766us
# 62:	learn: 0.2800634	total: 12.1ms	remaining: 573us
# 63:	learn: 0.2733722	total: 12.2ms	remaining: 381us
# 64:	learn: 0.2707685	total: 12.4ms	remaining: 191us
# 65:	learn: 0.2655756	total: 12.7ms	remaining: 0us
# 0:	learn: 1.1581587	total: 268us	remaining: 17.5ms
# 1:	learn: 1.1123330	total: 487us	remaining: 15.6ms
# 2:	learn: 1.0830689	total: 691us	remaining: 14.5ms
# 3:	learn: 1.0709678	total: 895us	remaining: 13.9ms
# 4:	learn: 1.0312428	total: 1.08ms	remaining: 13.2ms
# 5:	learn: 0.9933869	total: 1.25ms	remaining: 12.5ms
# 6:	learn: 0.9761948	total: 1.42ms	remaining: 12ms
# 7:	learn: 0.9458095	total: 1.6ms	remaining: 11.6ms
# 8:	learn: 0.9160311	total: 1.77ms	remaining: 11.2ms
# 9:	learn: 0.8898556	total: 1.95ms	remaining: 10.9ms
# 10:	learn: 0.8594433	total: 2.13ms	remaining: 10.7ms
# 11:	learn: 0.8386126	total: 2.42ms	remaining: 10.9ms
# 12:	learn: 0.8190997	total: 2.63ms	remaining: 10.7ms
# 13:	learn: 0.7931553	total: 2.83ms	remaining: 10.5ms
# 14:	learn: 0.7631511	total: 3.05ms	remaining: 10.4ms
# 15:	learn: 0.7493751	total: 3.27ms	remaining: 10.2ms
# 16:	learn: 0.7332496	total: 3.46ms	remaining: 9.98ms
# 17:	learn: 0.7080163	total: 3.64ms	remaining: 9.71ms
# 18:	learn: 0.6813081	total: 3.88ms	remaining: 9.59ms
# 19:	learn: 0.6673436	total: 4.1ms	remaining: 9.43ms
# 20:	learn: 0.6488437	total: 4.29ms	remaining: 9.19ms
# 21:	learn: 0.6340901	total: 4.48ms	remaining: 8.96ms
# 22:	learn: 0.6233443	total: 4.69ms	remaining: 8.77ms
# 23:	learn: 0.6079058	total: 4.87ms	remaining: 8.52ms
# 24:	learn: 0.5927961	total: 5.05ms	remaining: 8.28ms
# 25:	learn: 0.5700231	total: 5.22ms	remaining: 8.03ms
# 26:	learn: 0.5631171	total: 5.39ms	remaining: 7.79ms
# 27:	learn: 0.5574848	total: 5.58ms	remaining: 7.57ms
# 28:	learn: 0.5449102	total: 5.75ms	remaining: 7.34ms
# 29:	learn: 0.5326512	total: 5.92ms	remaining: 7.11ms
# 30:	learn: 0.5225656	total: 6.09ms	remaining: 6.88ms
# 31:	learn: 0.5149908	total: 6.3ms	remaining: 6.69ms
# 32:	learn: 0.5044848	total: 6.48ms	remaining: 6.48ms
# 33:	learn: 0.4955877	total: 6.67ms	remaining: 6.28ms
# 34:	learn: 0.4838756	total: 6.86ms	remaining: 6.07ms
# 35:	learn: 0.4783827	total: 7.04ms	remaining: 5.87ms
# 36:	learn: 0.4732960	total: 7.25ms	remaining: 5.68ms
# 37:	learn: 0.4591842	total: 7.53ms	remaining: 5.55ms
# 38:	learn: 0.4457831	total: 7.76ms	remaining: 5.37ms
# 39:	learn: 0.4395118	total: 7.96ms	remaining: 5.17ms
# 40:	learn: 0.4283936	total: 8.16ms	remaining: 4.97ms
# 41:	learn: 0.4214470	total: 8.35ms	remaining: 4.77ms
# 42:	learn: 0.4181721	total: 8.53ms	remaining: 4.56ms
# 43:	learn: 0.4063612	total: 8.71ms	remaining: 4.35ms
# 44:	learn: 0.3971861	total: 8.9ms	remaining: 4.16ms
# 45:	learn: 0.3867327	total: 9.1ms	remaining: 3.96ms
# 46:	learn: 0.3821459	total: 9.29ms	remaining: 3.75ms
# 47:	learn: 0.3772345	total: 9.47ms	remaining: 3.55ms
# 48:	learn: 0.3729241	total: 9.66ms	remaining: 3.35ms
# 49:	learn: 0.3683096	total: 9.84ms	remaining: 3.15ms
# 50:	learn: 0.3647503	total: 10ms	remaining: 2.95ms
# 51:	learn: 0.3556275	total: 10.2ms	remaining: 2.75ms
# 52:	learn: 0.3513511	total: 10.4ms	remaining: 2.55ms
# 53:	learn: 0.3472709	total: 10.6ms	remaining: 2.36ms
# 54:	learn: 0.3429670	total: 10.8ms	remaining: 2.16ms
# 55:	learn: 0.3392818	total: 11ms	remaining: 1.96ms
# 56:	learn: 0.3352835	total: 11.2ms	remaining: 1.76ms
# 57:	learn: 0.3322316	total: 11.3ms	remaining: 1.56ms
# 58:	learn: 0.3290787	total: 11.5ms	remaining: 1.36ms
# 59:	learn: 0.3258746	total: 11.7ms	remaining: 1.17ms
# 60:	learn: 0.3229476	total: 11.9ms	remaining: 974us
# 61:	learn: 0.3198011	total: 12.1ms	remaining: 778us
# 62:	learn: 0.3122923	total: 12.3ms	remaining: 583us
# 63:	learn: 0.3095682	total: 12.4ms	remaining: 388us
# 64:	learn: 0.3070430	total: 12.6ms	remaining: 194us
# 65:	learn: 0.2974285	total: 12.8ms	remaining: 0us
# 0:	learn: 1.2796282	total: 286us	remaining: 18.6ms
# 1:	learn: 1.2197706	total: 501us	remaining: 16ms
# 2:	learn: 1.1794556	total: 688us	remaining: 14.5ms
# 3:	learn: 1.1317732	total: 877us	remaining: 13.6ms
# 4:	learn: 1.0780366	total: 1.06ms	remaining: 12.9ms
# 5:	learn: 1.0393012	total: 1.25ms	remaining: 12.5ms
# 6:	learn: 0.9899465	total: 1.43ms	remaining: 12ms
# 7:	learn: 0.9517208	total: 1.68ms	remaining: 12.1ms
# 8:	learn: 0.9229194	total: 1.89ms	remaining: 12ms
# 9:	learn: 0.8878603	total: 2.12ms	remaining: 11.9ms
# 10:	learn: 0.8683117	total: 2.37ms	remaining: 11.8ms
# 11:	learn: 0.8414796	total: 2.6ms	remaining: 11.7ms
# 12:	learn: 0.8119297	total: 2.8ms	remaining: 11.4ms
# 13:	learn: 0.7828401	total: 2.99ms	remaining: 11.1ms
# 14:	learn: 0.7485081	total: 3.21ms	remaining: 10.9ms
# 15:	learn: 0.7347113	total: 3.46ms	remaining: 10.8ms
# 16:	learn: 0.7124554	total: 3.65ms	remaining: 10.5ms
# 17:	learn: 0.6846479	total: 3.83ms	remaining: 10.2ms
# 18:	learn: 0.6640094	total: 4.02ms	remaining: 9.95ms
# 19:	learn: 0.6481381	total: 4.24ms	remaining: 9.74ms
# 20:	learn: 0.6331647	total: 4.43ms	remaining: 9.49ms
# 21:	learn: 0.6208186	total: 4.64ms	remaining: 9.28ms
# 22:	learn: 0.5992358	total: 4.88ms	remaining: 9.12ms
# 23:	learn: 0.5779275	total: 5.06ms	remaining: 8.86ms
# 24:	learn: 0.5649750	total: 5.35ms	remaining: 8.78ms
# 25:	learn: 0.5459035	total: 5.56ms	remaining: 8.56ms
# 26:	learn: 0.5391354	total: 5.85ms	remaining: 8.45ms
# 27:	learn: 0.5336721	total: 6.05ms	remaining: 8.22ms
# 28:	learn: 0.5212245	total: 6.22ms	remaining: 7.94ms
# 29:	learn: 0.5092324	total: 6.4ms	remaining: 7.67ms
# 30:	learn: 0.4984394	total: 6.65ms	remaining: 7.51ms
# 31:	learn: 0.4896975	total: 6.85ms	remaining: 7.28ms
# 32:	learn: 0.4822429	total: 7.04ms	remaining: 7.04ms
# 33:	learn: 0.4766563	total: 7.22ms	remaining: 6.79ms
# 34:	learn: 0.4703888	total: 7.45ms	remaining: 6.6ms
# 35:	learn: 0.4641301	total: 7.69ms	remaining: 6.41ms
# 36:	learn: 0.4595079	total: 7.87ms	remaining: 6.17ms
# 37:	learn: 0.4506606	total: 8.04ms	remaining: 5.93ms
# 38:	learn: 0.4455830	total: 8.22ms	remaining: 5.69ms
# 39:	learn: 0.4385663	total: 8.41ms	remaining: 5.47ms
# 40:	learn: 0.4287100	total: 8.58ms	remaining: 5.23ms
# 41:	learn: 0.4195415	total: 8.76ms	remaining: 5ms
# 42:	learn: 0.4078757	total: 8.93ms	remaining: 4.77ms
# 43:	learn: 0.3981414	total: 9.17ms	remaining: 4.58ms
# 44:	learn: 0.3940164	total: 9.35ms	remaining: 4.37ms
# 45:	learn: 0.3889311	total: 9.54ms	remaining: 4.15ms
# 46:	learn: 0.3814251	total: 9.73ms	remaining: 3.93ms
# 47:	learn: 0.3776764	total: 9.96ms	remaining: 3.74ms
# 48:	learn: 0.3740067	total: 10.1ms	remaining: 3.52ms
# 49:	learn: 0.3710303	total: 10.3ms	remaining: 3.31ms
# 50:	learn: 0.3689209	total: 10.5ms	remaining: 3.09ms
# 51:	learn: 0.3604513	total: 10.7ms	remaining: 2.88ms
# 52:	learn: 0.3571635	total: 10.9ms	remaining: 2.68ms
# 53:	learn: 0.3452508	total: 11.1ms	remaining: 2.47ms
# 54:	learn: 0.3425962	total: 11.3ms	remaining: 2.26ms
# 55:	learn: 0.3399299	total: 11.5ms	remaining: 2.05ms
# 56:	learn: 0.3373292	total: 11.7ms	remaining: 1.85ms
# 57:	learn: 0.3346268	total: 11.9ms	remaining: 1.65ms
# 58:	learn: 0.3266459	total: 12.1ms	remaining: 1.44ms
# 59:	learn: 0.3239126	total: 12.3ms	remaining: 1.23ms
# 60:	learn: 0.3213302	total: 12.5ms	remaining: 1.02ms
# 61:	learn: 0.3192394	total: 12.7ms	remaining: 819us
# 62:	learn: 0.3147417	total: 12.9ms	remaining: 613us
# 63:	learn: 0.3070037	total: 13.1ms	remaining: 408us
# 64:	learn: 0.3048087	total: 13.3ms	remaining: 205us
# 65:	learn: 0.2968771	total: 13.5ms	remaining: 0us
# 0:	learn: 1.2446310	total: 299us	remaining: 19.4ms
# 1:	learn: 1.1900487	total: 526us	remaining: 16.8ms
# 2:	learn: 1.1478536	total: 740us	remaining: 15.6ms
# 3:	learn: 1.1104991	total: 1.02ms	remaining: 15.7ms
# 4:	learn: 1.0642878	total: 1.23ms	remaining: 15ms
# 5:	learn: 1.0161585	total: 1.42ms	remaining: 14.2ms
# 6:	learn: 0.9745356	total: 1.6ms	remaining: 13.5ms
# 7:	learn: 0.9453257	total: 1.85ms	remaining: 13.4ms
# 8:	learn: 0.9117771	total: 2.07ms	remaining: 13.1ms
# 9:	learn: 0.8824084	total: 2.26ms	remaining: 12.6ms
# 10:	learn: 0.8426681	total: 2.45ms	remaining: 12.2ms
# 11:	learn: 0.8222410	total: 2.73ms	remaining: 12.3ms
# 12:	learn: 0.7927237	total: 3.09ms	remaining: 12.6ms
# 13:	learn: 0.7569547	total: 3.61ms	remaining: 13.4ms
# 14:	learn: 0.7210710	total: 3.84ms	remaining: 13.1ms
# 15:	learn: 0.7011211	total: 4.03ms	remaining: 12.6ms
# 16:	learn: 0.6790263	total: 4.22ms	remaining: 12.2ms
# 17:	learn: 0.6650935	total: 4.46ms	remaining: 11.9ms
# 18:	learn: 0.6464347	total: 4.67ms	remaining: 11.6ms
# 19:	learn: 0.6238563	total: 4.86ms	remaining: 11.2ms
# 20:	learn: 0.6086583	total: 5.03ms	remaining: 10.8ms
# 21:	learn: 0.5871007	total: 5.25ms	remaining: 10.5ms
# 22:	learn: 0.5756653	total: 5.46ms	remaining: 10.2ms
# 23:	learn: 0.5619776	total: 5.65ms	remaining: 9.88ms
# 24:	learn: 0.5498132	total: 5.83ms	remaining: 9.56ms
# 25:	learn: 0.5420370	total: 6.05ms	remaining: 9.31ms
# 26:	learn: 0.5328559	total: 6.3ms	remaining: 9.1ms
# 27:	learn: 0.5251852	total: 6.49ms	remaining: 8.8ms
# 28:	learn: 0.5101557	total: 6.67ms	remaining: 8.51ms
# 29:	learn: 0.4971634	total: 6.86ms	remaining: 8.23ms
# 30:	learn: 0.4850840	total: 7.06ms	remaining: 7.97ms
# 31:	learn: 0.4779729	total: 7.26ms	remaining: 7.71ms
# 32:	learn: 0.4715040	total: 7.45ms	remaining: 7.45ms
# 33:	learn: 0.4629187	total: 7.63ms	remaining: 7.18ms
# 34:	learn: 0.4539404	total: 7.85ms	remaining: 6.95ms
# 35:	learn: 0.4492302	total: 8.06ms	remaining: 6.72ms
# 36:	learn: 0.4441534	total: 8.25ms	remaining: 6.47ms
# 37:	learn: 0.4373519	total: 8.44ms	remaining: 6.22ms
# 38:	learn: 0.4307881	total: 8.63ms	remaining: 5.98ms
# 39:	learn: 0.4222492	total: 8.86ms	remaining: 5.76ms
# 40:	learn: 0.4194094	total: 9.06ms	remaining: 5.52ms
# 41:	learn: 0.4150422	total: 9.24ms	remaining: 5.28ms
# 42:	learn: 0.4116127	total: 9.47ms	remaining: 5.06ms
# 43:	learn: 0.4010258	total: 9.71ms	remaining: 4.85ms
# 44:	learn: 0.3895589	total: 9.9ms	remaining: 4.62ms
# 45:	learn: 0.3833554	total: 10.1ms	remaining: 4.39ms
# 46:	learn: 0.3772017	total: 10.3ms	remaining: 4.18ms
# 47:	learn: 0.3728087	total: 10.5ms	remaining: 3.95ms
# 48:	learn: 0.3676991	total: 10.7ms	remaining: 3.72ms
# 49:	learn: 0.3636021	total: 10.9ms	remaining: 3.49ms
# 50:	learn: 0.3617777	total: 11.1ms	remaining: 3.26ms
# 51:	learn: 0.3517259	total: 11.3ms	remaining: 3.04ms
# 52:	learn: 0.3486701	total: 11.5ms	remaining: 2.81ms
# 53:	learn: 0.3406378	total: 11.6ms	remaining: 2.59ms
# 54:	learn: 0.3368833	total: 11.8ms	remaining: 2.36ms
# 55:	learn: 0.3334707	total: 12ms	remaining: 2.15ms
# 56:	learn: 0.3294957	total: 12.2ms	remaining: 1.93ms
# 57:	learn: 0.3253376	total: 12.4ms	remaining: 1.72ms
# 58:	learn: 0.3217435	total: 12.6ms	remaining: 1.5ms
# 59:	learn: 0.3172714	total: 12.8ms	remaining: 1.28ms
# 60:	learn: 0.3144549	total: 13ms	remaining: 1.07ms
# 61:	learn: 0.3098929	total: 13.2ms	remaining: 852us
# 62:	learn: 0.3067140	total: 13.4ms	remaining: 637us
# 63:	learn: 0.3032721	total: 13.6ms	remaining: 423us
# 64:	learn: 0.3007925	total: 13.8ms	remaining: 211us
# 65:	learn: 0.2978938	total: 14ms	remaining: 0us
# Best parameters: {'depth': 4, 'iterations': 66, 'learning_rate': 0.109}
# Training set R2 score: 0.9476740365222434
# Training set MAE: 0.2438280690980957
# Training set MSE: 0.08874074248429474
# Training set RMSE: 0.29789384432091703
# Test set R2 score: 0.9357052576816409
# Test set MAE: 0.3173446358108244
# Test set MSE: 0.1735472770918306
# Test set RMSE: 0.41659005880101196
